# %%
import pandas as pd
weatherdata  = pd.read_csv("datasets/weatherHistory.csv")
data = weatherdata.drop(['Formatted Date','Daily Summary'], axis =1)
data.dropna()
data.reset_index(inplace = True)
data = data.drop(['Summary','Precip Type'], axis = 1)
data = data.drop('Loud Cover', axis = 1)
import matplotlib.pyplot as mlt
data_corr = data.corr()
import numpy as np
import seaborn as sns
mlt.subplots(figsize=(20,15))
sns.heatmap(data.corr(), annot =True)
data = data.drop(['Humidity','Wind Speed (km/h)','Pressure (millibars)'], axis =True)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
X = data.drop(['index','Apparent Temperature (C)'], axis =1)
Y = data['Apparent Temperature (C)']
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.20)
model = LinearRegression()
train_model = model.fit(X_train,Y_train)

# %%
predict_data = train_model.predict(da)

# %%
train_model.score(X_test,Y_test)
# Out:
# 0.9853642202448654

# %%
type(X_test)
# Out:
# pandas.core.frame.DataFrame

# %%
X_test
# Out:
#        Temperature (C)  Wind Bearing (degrees)  Visibility (km)
# 52361        26.000000                   342.0          10.3523
# 35943        32.061111                    10.0          11.2700
# 16914        17.777778                   309.0          11.2056
# 25373        10.994444                   150.0          11.1251
# 38463        -6.133333                   182.0           3.5259
# ...                ...                     ...              ...
# 87389        13.994444                   226.0           7.0196
# 86637         6.600000                   320.0           3.9123
# 88936        25.044444                   329.0          16.1000
# 87630        14.933333                   338.0          10.2557
# 28993        -0.505556                   274.0          13.9587
#
# [19291 rows x 3 columns]

# %%
d = {'Temperature (c)':26.016667, 'Wind Bearing (degrees)':31.0,'Visibility (km)':16.1000}

# %%
da = pd.DataFrame(d, index = [1])

# %%
da
# Out:
#    Temperature (c)  Wind Bearing (degrees)  Visibility (km)
# 1        26.016667                    31.0             16.1

# %%
predict_data
# Out:
# array([26.43695905])

# %%
data
# Out:
#        index  Temperature (C)  Apparent Temperature (C)  \
# 0          0         9.472222                  7.388889
# 1          1         9.355556                  7.227778
# 2          2         9.377778                  9.377778
# 3          3         8.288889                  5.944444
# 4          4         8.755556                  6.977778
# ...      ...              ...                       ...
# 96448  96448        26.016667                 26.016667
# 96449  96449        24.583333                 24.583333
# 96450  96450        22.038889                 22.038889
# 96451  96451        21.522222                 21.522222
# 96452  96452        20.438889                 20.438889
#
#        Wind Bearing (degrees)  Visibility (km)
# 0                       251.0          15.8263
# 1                       259.0          15.8263
# 2                       204.0          14.9569
# 3                       269.0          15.8263
# 4                       259.0          15.8263
# ...

# %%
data
# Out:
#        index  Temperature (C)  Apparent Temperature (C)  \
# 0          0         9.472222                  7.388889
# 1          1         9.355556                  7.227778
# 2          2         9.377778                  9.377778
# 3          3         8.288889                  5.944444
# 4          4         8.755556                  6.977778
# ...      ...              ...                       ...
# 96448  96448        26.016667                 26.016667
# 96449  96449        24.583333                 24.583333
# 96450  96450        22.038889                 22.038889
# 96451  96451        21.522222                 21.522222
# 96452  96452        20.438889                 20.438889
#
#        Wind Bearing (degrees)  Visibility (km)
# 0                       251.0          15.8263
# 1                       259.0          15.8263
# 2                       204.0          14.9569
# 3                       269.0          15.8263
# 4                       259.0          15.8263
# ...

# %%
model
# Out:
# 0         7.388889
# 1         7.227778
# 2         9.377778
# 3         5.944444
# 4         6.977778
#            ...
# 96448    26.016667
# 96449    24.583333
# 96450    22.038889
# 96451    21.522222
# 96452    20.438889
# Name: Apparent Temperature (C), Length: 96453, dtype: float64

# %%
# Out:
#        Temperature (C)  Wind Bearing (degrees)  Visibility (km)
# 0             9.472222                   251.0          15.8263
# 1             9.355556                   259.0          15.8263
# 2             9.377778                   204.0          14.9569
# 3             8.288889                   269.0          15.8263
# 4             8.755556                   259.0          15.8263
# ...                ...                     ...              ...
# 96448        26.016667                    31.0          16.1000
# 96449        24.583333                    20.0          15.5526
# 96450        22.038889                    30.0          16.1000
# 96451        21.522222                    20.0          16.1000
# 96452        20.438889                    39.0          15.5204
#
# [96453 rows x 3 columns]

# %%
X
# Out:
#        index  Temperature (C)  Wind Bearing (degrees)  Visibility (km)
# 0          0         9.472222                   251.0          15.8263
# 1          1         9.355556                   259.0          15.8263
# 2          2         9.377778                   204.0          14.9569
# 3          3         8.288889                   269.0          15.8263
# 4          4         8.755556                   259.0          15.8263
# ...      ...              ...                     ...              ...
# 96448  96448        26.016667                    31.0          16.1000
# 96449  96449        24.583333                    20.0          15.5526
# 96450  96450        22.038889                    30.0          16.1000
# 96451  96451        21.522222                    20.0          16.1000
# 96452  96452        20.438889                    39.0          15.5204
#
# [96453 rows x 4 columns]

# %%
# Out:
#        index  Temperature (C)  Apparent Temperature (C)  \
# 0          0         9.472222                  7.388889
# 1          1         9.355556                  7.227778
# 2          2         9.377778                  9.377778
# 3          3         8.288889                  5.944444
# 4          4         8.755556                  6.977778
# ...      ...              ...                       ...
# 96448  96448        26.016667                 26.016667
# 96449  96449        24.583333                 24.583333
# 96450  96450        22.038889                 22.038889
# 96451  96451        21.522222                 21.522222
# 96452  96452        20.438889                 20.438889
#
#        Wind Bearing (degrees)  Visibility (km)
# 0                       251.0          15.8263
# 1                       259.0          15.8263
# 2                       204.0          14.9569
# 3                       269.0          15.8263
# 4                       259.0          15.8263
# ...

# %%
data
# Out:
#        index  Temperature (C)  Apparent Temperature (C)  Humidity  \
# 0          0         9.472222                  7.388889      0.89
# 1          1         9.355556                  7.227778      0.86
# 2          2         9.377778                  9.377778      0.89
# 3          3         8.288889                  5.944444      0.83
# 4          4         8.755556                  6.977778      0.83
# ...      ...              ...                       ...       ...
# 96448  96448        26.016667                 26.016667      0.43
# 96449  96449        24.583333                 24.583333      0.48
# 96450  96450        22.038889                 22.038889      0.56
# 96451  96451        21.522222                 21.522222      0.60
# 96452  96452        20.438889                 20.438889      0.61
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  \
# 0                14.1197                   251.0          15.8263
# ...
